# %%
import pandas as pd
import seaborn as sns
lines_vectors = pd.read_csv('../../../training_data.csv')
lines_data = sns.load_dataset(lines_vectors, True)
lines_data.head()
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-1aff1f696cdc> in <module>()
#       2 import seaborn as sns
#       3 lines_vectors = pd.read_csv('../../../training_data.csv')
# ----> 4 lines_data = sns.load_dataset(lines_vectors)
#       5 lines_data.head()
#
# /home/dasha/.local/lib/python2.7/site-packages/seaborn/utils.pyc in load_dataset(name, cache, data_home, **kws)
#     426                                   os.path.basename(full_path))
#     427         if not os.path.exists(cache_path):
# --> 428             urlretrieve(full_path, cache_path)
#     429         full_path = cache_path
#     430
#
# /usr/lib/python2.7/urllib.pyc in urlretrieve(url, filename, reporthook, data, context)
#      96     else:
#      97         opener = _urlopener
# ---> 98     return opener.retrieve(url, filename, reporthook, data)
#      99 def urlcleanup():
# ...
