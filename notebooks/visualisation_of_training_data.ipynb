# %%
import pandas as pd
import seaborn as sns
lines_vectors = pd.read_csv('../../../training_data.csv')
lines_vectors.head()
# Out:
#    words_num  awerage_word_length  italicness  type
# 0          1                  1.0         0.0  text
# 1          1                  1.0         0.0  text
# 2          1                  1.0         0.0  text
# 3          1                  1.0         0.0  text
# 4          2                  0.0         0.0  text

# %%
sns.pairplot(data=lines_vectors, hue="type", height=8)
